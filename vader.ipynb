# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
def sentiment_scores(sentence):
     
     pos_count=0
     neg_count=0
     neu_count=0
     sid_obj = SentimentIntensityAnalyzer()
def sentiment_scores(sentence):
     
     pos_count=0
     neg_count=0
     neu_count=0
     sid_obj = SentimentIntensityAnalyzer()
     sentiment_dict = sid_obj.polarity_scores(sentence) 
     print("Overall sentiment of each comment is : ", sentiment_dict) 
     print("comment is ", sentiment_dict['neg']*100, "% Negative") 
     print("comment is ", sentiment_dict['neu']*100, "% Neutral") 
     print("comment is ", sentiment_dict['pos']*100, "% Positive") 

  
     print("Comment is Overall Rated As", end = " ") 
     if sentiment_dict['compound'] >= 0.05 :
        print("Positive")
        pos_count=pos_count+1
  
     elif sentiment_dict['compound'] <= - 0.05 : 
        print("Negative")
        neg_count=neg_count+1
  
     else:
        print("Neutral") 
        neu_count=neu_count+1
     return pos_count,neg_count,neu_count


     sentiment_dict = sid_obj.polarity_scores(sentence) 
     print("Overall sentiment of each comment is : ", sentiment_dict) 
     print("comment is ", sentiment_dict['neg']*100, "% Negative") 
     print("comment is ", sentiment_dict['neu']*100, "% Neutral") 
     print("comment is ", sentiment_dict['pos']*100, "% Positive") 
     
  
     print("Comment is Overall Rated As", end = " ") 
     if sentiment_dict['compound'] >= 0.05 :
        print("Positive")
        pos_count=pos_count+1
  
     elif sentiment_dict['compound'] <= - 0.05 : 
        print("Negative")
        neg_count=neg_count+1
  
     else:
        print("Neutral") 
        neu_count=neu_count+1
     return pos_count,neg_count,neu_count

# %%
if __name__ == "__main__" :
    
    with open("C:/Users/pooji/OneDrive/Desktop/project.csv") as f:
        pc=0
        nc=0
        nec=0
        positive=0
        negative=0
        neutral=0
        for line in f:
            pos,neg,neu=sentiment_scores(line)
            if(pos==1):
                pc=pc+1
                #positive=positive+1
            elif(neg==1):
                nc=nc+1
                #negative=negative+1
        
            else:
                nec=nec+1
                #neutral=neutral+1
    
    pospercent=(pc/tot_count)*100
    negpercent=(nc/tot_count)*100
    neupercent=(nec/tot_count)*100
    print(pospercent)
    print(negpercent)
    print(neupercent)
# Out:
# Overall sentiment of each comment is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# comment is  0.0 % Negative
# comment is  100.0 % Neutral
# comment is  0.0 % Positive
# Comment is Overall Rated As Neutral
# Overall sentiment of each comment is :  {'neg': 0.045, 'neu': 0.841, 'pos': 0.114, 'compound': 0.8393}
# comment is  4.5 % Negative
# comment is  84.1 % Neutral
# comment is  11.4 % Positive
# Comment is Overall Rated As Positive
# Overall sentiment of each comment is :  {'neg': 0.098, 'neu': 0.804, 'pos': 0.098, 'compound': 0.0}
# comment is  9.8 % Negative
# comment is  80.4 % Neutral
# comment is  9.8 % Positive
# Comment is Overall Rated As Neutral
# Overall sentiment of each comment is :  {'neg': 0.018, 'neu': 0.898, 'pos': 0.084, 'compound': 0.6915}
# comment is  1.7999999999999998 % Negative
# comment is  89.8 % Neutral
# comment is  8.4 % Positive
# Comment is Overall Rated As Positive
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
labels=["Positive","Negative","Neutral"]
values=[pospercent,negpercent,neupercent]
explode=[0.05,0,0]
plt.pie(values,labels=labels,autopct="%.1f%%",explode=explode)
plt.title("Analysis of employee Reviews On Amazon")
plt.show()
